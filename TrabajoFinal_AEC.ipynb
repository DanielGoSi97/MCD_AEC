# %% [markdown]
# # Trabajo Final: Aprendizaje Supervisado y No Supervisado
#
# **Ramo:** Aprendizaje estadístico y computacional
# **Integrantes:** _(completar nombres del grupo)_
#
# Perfiles socioeconómicos de los países y su nivel de ingreso, a partir de indicadores del Banco Mundial.

# %% [markdown]
# ## Introducción
#
# En este informe trabajo con indicadores socioeconómicos de los países del mundo, obtenidos desde la API del Banco Mundial para el año 2022. La idea es doble. Por un lado quiero predecir el nivel de ingreso de un país a partir de sus características de desarrollo, usando aprendizaje supervisado. Por otro, quiero descubrir si al agrupar los países solo por esas características, sin mirar su ingreso, aparecen perfiles que coincidan o no con la clasificación oficial del Banco Mundial.
#
# El nivel de ingreso lo define el Banco Mundial a partir del ingreso nacional bruto per cápita, por lo que las variables monetarias quedan fuera del modelo para evitar circularidad. Predigo el ingreso desde indicadores no monetarios como la salud, la demografía y la conectividad.

# %% [markdown]
# ## Objetivos
#
# **Objetivo general**
# Identificar las características socioeconómicas asociadas al nivel de ingreso de los países y contrastar la clasificación oficial de ingreso del Banco Mundial con agrupamientos obtenidos directamente de los datos.
#
# **Objetivos específicos**
#
# - Caracterizar los países mediante un análisis exploratorio, tratando datos faltantes y valores atípicos.
# - Entrenar y comparar modelos de clasificación para predecir el grupo de ingreso e identificar las variables más influyentes.
# - Construir agrupamientos de países sin usar la variable respuesta y contrastarlos con la clasificación oficial de ingreso.

# %% [markdown]
# ## 1. Librerías
#
# Importo las librerías que voy a usar a lo largo del trabajo.

# %%
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import (accuracy_score, balanced_accuracy_score, precision_score,
                             recall_score, f1_score, roc_auc_score, roc_curve,
                             confusion_matrix, classification_report)
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from scipy.cluster.hierarchy import dendrogram, linkage

pd.set_option("display.float_format", lambda x: f"{x:,.2f}")
plt.rcParams["figure.figsize"] = (8, 5)
RANDOM_STATE = 42

# %% [markdown]
# ## 2. Descarga de los datos desde la API del Banco Mundial
#
# Cada indicador es una llamada aparte a la API, identificado por su código. Defino una función que trae un indicador para todos los países en un año y devuelve un DataFrame con el código ISO de 3 letras y el valor.

# %%
def traer_indicador(codigo, nombre, anio=2022):
    url = f"http://api.worldbank.org/v2/country/all/indicator/{codigo}"
    params = {"format": "json", "date": anio, "per_page": 1000}
    rpta = requests.get(url, params=params).json()[1]
    df = pd.json_normalize(rpta)[["countryiso3code", "value"]]
    # Los agregados regionales llegan con código vacío; los quito para que el
    # merge por país no genere un producto cartesiano entre indicadores.
    df = df[df["countryiso3code"].str.len() == 3]
    return df.rename(columns={"value": nombre})

# Indicadores no monetarios que uso como covariables
indicadores = {
    "SP.DYN.LE00.IN":     "Esperanza_vida",
    "SP.DYN.TFRT.IN":     "Fecundidad",
    "SP.URB.TOTL.IN.ZS":  "Urbana_pct",
    "IT.NET.USER.ZS":     "Internet_pct",
    "SH.DYN.MORT":        "Mortalidad_u5",
    "SH.XPD.CHEX.GD.ZS":  "Gasto_salud_pctPIB",
    "EG.ELC.ACCS.ZS":     "Acceso_electricidad_pct",
    "SP.POP.TOTL":        "Poblacion",
    "NY.GDP.PCAP.CD":     "PIB_per_capita",
}

frames = [traer_indicador(cod, nom) for cod, nom in indicadores.items()]
print("Indicadores descargados:", len(frames))
# Out:
# Indicadores descargados: 9

# %% [markdown]
# Uno todos los indicadores en una sola tabla usando el código ISO del país como llave.

# %%
from functools import reduce
df = reduce(lambda a, b: a.merge(b, on="countryiso3code", how="outer"), frames)
print(df.shape)
df.head()
# Out:
# (260, 10)
#   countryiso3code  Esperanza_vida  Fecundidad  Urbana_pct  Internet_pct  \
# 0             ABW           76.23        1.61       61.88           NaN
# 1             AFE           64.49        4.29       37.36         26.80
# 2             AFG           65.62        4.93       25.39         15.87
# 3             AFW           57.98        4.56       51.70         37.50
# 4             AGO           64.25        5.21       69.05         35.84
#
#    Mortalidad_u5  Gasto_salud_pctPIB  Acceso_electricidad_pct      Poblacion  \
# 0            NaN                 NaN                    99.90     107,310.00
# 1          63.21                5.57                    48.74 731,821,393.00
# 2          56.80               23.09                    85.30  40,578,842.00
# 3          99.28                4.17                    55.59 496,366,058.00
# 4          51.90                2.60                    48.50  35,635,029.00
#
#    PIB_per_capita
# 0       31,000.57
# 1        1,675.90
# 2          357.26
# 3        2,143.07
# 4        3,598.54

# %% [markdown]
# La variable respuesta, el nivel de ingreso, no viene en los indicadores. La saco del endpoint de países, que además trae la región. Ese endpoint mezcla países reales con agregados regionales, así que aprovecho la región para filtrarlos después.

# %%
url_paises = "http://api.worldbank.org/v2/country"
rpta = requests.get(url_paises, params={"format": "json", "per_page": 400}).json()[1]
meta = pd.json_normalize(rpta)[["id", "name", "region.value", "incomeLevel.id", "incomeLevel.value"]]
meta = meta.rename(columns={"id": "countryiso3code", "name": "Pais",
                            "region.value": "Region",
                            "incomeLevel.id": "Ingreso_id",
                            "incomeLevel.value": "Ingreso"})
df = df.merge(meta, on="countryiso3code", how="left")
print(df.shape)
df[["countryiso3code", "Pais", "Region", "Ingreso"]].head()
# Out:
# (260, 14)
#   countryiso3code                         Pais  \
# 0             ABW                        Aruba
# 1             AFE  Africa Eastern and Southern
# 2             AFG                  Afghanistan
# 3             AFW   Africa Western and Central
# 4             AGO                       Angola
#
#                                               Region              Ingreso
# 0                         Latin America & Caribbean           High income
# 1                                         Aggregates           Aggregates
# 2  Middle East, North Africa, Afghanistan & Pakistan           Low income
# 3                                         Aggregates           Aggregates
# 4                                Sub-Saharan Africa   Lower middle income

# %% [markdown]
# Filtro los agregados. Los agregados regionales tienen la región marcada como "Aggregates" y el nivel de ingreso como "NA", así que me quedo solo con los países reales.

# %%
antes = df.shape[0]
df = df[(df["Region"] != "Aggregates") & (df["Ingreso_id"] != "NA")].copy()
df = df.set_index("Pais")
print(f"De {antes} filas quedaron {df.shape[0]} países reales")
df["Ingreso"].value_counts()
# Out:
# De 260 filas quedaron 217 países reales
# Ingreso
# High income            86
# Upper middle income    59
# Lower middle income    47
# Low income             25
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Análisis exploratorio de datos
#
# Reviso la estructura, los estadísticos y los datos faltantes.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 217 entries, Aruba to Zimbabwe
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   countryiso3code          217 non-null    str
#  1   Esperanza_vida           217 non-null    float64
#  2   Fecundidad               217 non-null    float64
#  3   Urbana_pct               217 non-null    float64
#  4   Internet_pct             182 non-null    float64
#  5   Mortalidad_u5            196 non-null    float64
#  6   Gasto_salud_pctPIB       192 non-null    float64
#  7   Acceso_electricidad_pct  215 non-null    float64
#  8   Poblacion                217 non-null    float64
#  9   PIB_per_capita           209 non-null    float64
#  10  Region                   217 non-null    str
#  11  Ingreso_id               217 non-null    str
#  12  Ingreso                  217 non-null    str
# dtypes: float64(9), str(4)
# memory usage: 35.4 KB

# %%
df.describe().T
# Out:
#                          count          mean            std      min  \
# Esperanza_vida          217.00         73.11           7.94    18.82
# Fecundidad              217.00          2.41           1.22     0.68
# Urbana_pct              217.00         62.35          23.33    14.69
# Internet_pct            182.00         70.24          25.27     7.14
# Mortalidad_u5           196.00         27.21          38.87     1.40
# Gasto_salud_pctPIB      192.00          6.83           3.37     1.77
# Acceso_electricidad_pct 215.00         87.49          23.16     8.40
# Poblacion               217.00 36,706,746.19 141,528,692.84 9,992.00
# PIB_per_capita          209.00     21,200.87      31,131.45   301.83
#
#                                25%          50%           75%              max
# Esperanza_vida               67.79        74.21         78.53            85.75
# Fecundidad                    1.51         1.95          3.17             6.25
# Urbana_pct                   42.73        63.31         81.16           100.00
# Internet_pct                 57.00        78.78         89.50           100.00
# Mortalidad_u5                 6.17        14.90         38.80           424.60
# Gasto_salud_pctPIB            4.33         6.55          8.68            23.09
# Acceso_electricidad_pct      86.50       100.00        100.00           100.00
# Poblacion               821,637.00 6,664,449.00 26,018,721.00 1,425,423,212.00
# PIB_per_capita            2,899.16     7,655.59     28,360.30       226,052.06

# %% [markdown]
# Cuento los datos faltantes por variable.

# %%
faltantes = df.isna().sum().sort_values(ascending=False)
print(faltantes)
faltantes[faltantes > 0].plot(kind="barh", color="#1F4E78")
plt.title("Datos faltantes por variable")
plt.xlabel("N° de países sin dato")
plt.tight_layout(); plt.show()
# Out:
# Internet_pct               35
# Gasto_salud_pctPIB         25
# Mortalidad_u5              21
# PIB_per_capita              8
# Acceso_electricidad_pct     2
# Urbana_pct                  0
# Fecundidad                  0
# Esperanza_vida              0
# countryiso3code             0
# Poblacion                   0
# Region                      0
# Ingreso_id                  0
# Ingreso                     0
# dtype: int64

# %% [markdown]
# Miro la distribución de las covariables no monetarias con histogramas.

# %%
covariables = ["Esperanza_vida", "Fecundidad", "Urbana_pct", "Internet_pct",
               "Mortalidad_u5", "Gasto_salud_pctPIB", "Acceso_electricidad_pct"]
df[covariables].hist(bins=25, figsize=(12, 8), color="#1F4E78")
plt.suptitle("Distribución de las covariables")
plt.tight_layout(); plt.show()

# %% [markdown]
# Reviso las correlaciones entre las covariables para anticipar redundancias.

# %%
corr = df[covariables].corr()
fig, ax = plt.subplots(figsize=(7, 6))
im = ax.imshow(corr, cmap="RdBu_r", vmin=-1, vmax=1)
ax.set_xticks(range(len(covariables))); ax.set_xticklabels(covariables, rotation=90)
ax.set_yticks(range(len(covariables))); ax.set_yticklabels(covariables)
for i in range(len(covariables)):
    for j in range(len(covariables)):
        ax.text(j, i, f"{corr.iloc[i,j]:.2f}", ha="center", va="center", fontsize=8)
fig.colorbar(im); plt.title("Matriz de correlación"); plt.tight_layout(); plt.show()

# %% [markdown]
# Reviso valores atípicos con diagramas de caja sobre las covariables estandarizadas, para poder compararlas en una misma escala.

# %%
from sklearn.preprocessing import StandardScaler as _SS
Z = pd.DataFrame(_SS().fit_transform(df[covariables].fillna(df[covariables].median())),
                 columns=covariables)
Z.boxplot(rot=90, figsize=(10, 5))
plt.title("Valores atípicos (covariables estandarizadas)")
plt.tight_layout(); plt.show()

# %% [markdown]
# ### Tratamiento de datos faltantes
#
# Los faltantes son pocos y se concentran en el gasto en salud, el uso de internet y la mortalidad. Como el objetivo no es imputar con precisión sino tener una tabla completa para modelar, imputo cada covariable con su mediana, que es robusta frente a los atípicos que vi arriba.

# %%
df[covariables] = df[covariables].fillna(df[covariables].median())
print("Faltantes en covariables tras imputar:", int(df[covariables].isna().sum().sum()))
# Out:
# Faltantes en covariables tras imputar: 0

# %% [markdown]
# ## 4. Aprendizaje supervisado
#
# ### Variable respuesta
#
# El nivel de ingreso oficial tiene cuatro categorías. Las clases quedan muy desbalanceadas, así que binarizo el problema en países de ingreso alto frente al resto. Esto vuelve natural el balanceo de clases y la búsqueda de una probabilidad de corte óptima.

# %%
df["y"] = (df["Ingreso_id"] == "HIC").astype(int)
print(df["y"].value_counts())
print("\nProporción de ingreso alto:", round(df["y"].mean(), 3))
# Out:
# y
# 0    131
# 1     86
# Name: count, dtype: int64
#
# Proporción de ingreso alto: 0.396

# %% [markdown]
# Separo en entrenamiento y prueba de forma estratificada, para conservar la proporción de clases, y estandarizo las covariables ajustando el escalador solo con el entrenamiento.

# %%
X = df[covariables]
y = df["y"]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, stratify=y, random_state=RANDOM_STATE)

scaler = StandardScaler().fit(X_train)
X_train_s = scaler.transform(X_train)
X_test_s = scaler.transform(X_test)
print("Train:", X_train.shape, " Test:", X_test.shape)
# Out:
# Train: (151, 7)  Test: (66, 7)

# %% [markdown]
# Entreno cuatro modelos de clasificación. En los que lo permiten activo el balanceo de clases con `class_weight='balanced'`. Comparo con varios indicadores porque, al haber desbalance, la exactitud sola engaña.

# %%
modelos = {
    "Regresión logística": LogisticRegression(max_iter=1000, class_weight="balanced"),
    "Árbol de decisión":   DecisionTreeClassifier(max_depth=4, class_weight="balanced",
                                                  random_state=RANDOM_STATE),
    "Random Forest":       RandomForestClassifier(n_estimators=300, class_weight="balanced",
                                                  random_state=RANDOM_STATE),
    "Gradient Boosting":   GradientBoostingClassifier(random_state=RANDOM_STATE),
}

filas = []
for nombre, modelo in modelos.items():
    modelo.fit(X_train_s, y_train)
    pred = modelo.predict(X_test_s)
    proba = modelo.predict_proba(X_test_s)[:, 1]
    filas.append({
        "Modelo": nombre,
        "Exactitud": accuracy_score(y_test, pred),
        "Exactitud balanceada": balanced_accuracy_score(y_test, pred),
        "Precisión": precision_score(y_test, pred),
        "Recall": recall_score(y_test, pred),
        "F1": f1_score(y_test, pred),
        "ROC-AUC": roc_auc_score(y_test, proba),
    })

resultados = pd.DataFrame(filas).set_index("Modelo").sort_values("F1", ascending=False)
resultados
# Out:
#                      Exactitud  Exactitud balanceada  Precisión  Recall   F1  \
# Modelo
# Árbol de decisión         0.82                  0.80       0.82    0.69 0.75
# Random Forest             0.79                  0.78       0.73    0.73 0.73
# Regresión logística       0.76                  0.76       0.67    0.77 0.71
# Gradient Boosting         0.77                  0.75       0.76    0.62 0.68
#
#                      ROC-AUC
# Modelo
# Árbol de decisión       0.82
# Random Forest           0.91
# Regresión logística     0.89
# Gradient Boosting       0.88

# %% [markdown]
# Comparo las curvas ROC de los modelos.

# %%
plt.figure()
for nombre, modelo in modelos.items():
    proba = modelo.predict_proba(X_test_s)[:, 1]
    fpr, tpr, _ = roc_curve(y_test, proba)
    plt.plot(fpr, tpr, label=f"{nombre} (AUC={roc_auc_score(y_test, proba):.2f})")
plt.plot([0, 1], [0, 1], "k--", alpha=0.5)
plt.xlabel("Tasa de falsos positivos"); plt.ylabel("Tasa de verdaderos positivos")
plt.title("Curvas ROC"); plt.legend(); plt.tight_layout(); plt.show()

# %% [markdown]
# ### Selección del mejor modelo
#
# Elijo el modelo con mejor F1, que equilibra precisión y recall bajo el desbalance de clases. Muestro su matriz de confusión y su reporte de clasificación.

# %%
mejor_nombre = resultados.index[0]
mejor = modelos[mejor_nombre]
pred = mejor.predict(X_test_s)
print("Mejor modelo:", mejor_nombre)
print("\nMatriz de confusión:\n", confusion_matrix(y_test, pred))
print("\n", classification_report(y_test, pred, target_names=["Resto", "Ingreso alto"]))
# Out:
# Mejor modelo: Árbol de decisión
#
# Matriz de confusión:
#  [[36  4]
#  [ 8 18]]
#
#                precision    recall  f1-score   support
#
#        Resto       0.82      0.90      0.86        40
# Ingreso alto       0.82      0.69      0.75        26
#
#     accuracy                           0.82        66
#    macro avg       0.82      0.80      0.80        66
# weighted avg       0.82      0.82      0.81        66

# %% [markdown]
# ### Probabilidad de corte óptima
#
# El umbral por defecto es 0.5. Busco el corte que maximiza el índice de Youden sobre la curva ROC, es decir el punto que mejor separa ambas clases, y vuelvo a evaluar el modelo con ese umbral.

# %%
proba = mejor.predict_proba(X_test_s)[:, 1]
fpr, tpr, thr = roc_curve(y_test, proba)
j = tpr - fpr
corte = thr[np.argmax(j)]
print(f"Probabilidad de corte óptima (Youden): {corte:.3f}")

pred_corte = (proba >= corte).astype(int)
print("\nCon umbral 0.5   -> F1:", round(f1_score(y_test, pred), 3))
print("Con umbral óptimo -> F1:", round(f1_score(y_test, pred_corte), 3))
print("\nMatriz de confusión con umbral óptimo:\n", confusion_matrix(y_test, pred_corte))
# Out:
# Probabilidad de corte óptima (Youden): 0.603
#
# Con umbral 0.5   -> F1: 0.75
# Con umbral óptimo -> F1: 0.75
#
# Matriz de confusión con umbral óptimo:
#  [[36  4]
#  [ 8 18]]

# %% [markdown]
# ### Variables más influyentes
#
# Reviso qué covariables pesan más en la predicción, según la importancia del modelo elegido.

# %%
if hasattr(mejor, "feature_importances_"):
    imp = pd.Series(mejor.feature_importances_, index=covariables)
    titulo = "Importancia de variables"
else:
    imp = pd.Series(np.abs(mejor.coef_[0]), index=covariables)
    titulo = "Peso de variables (|coef| regresión logística)"
imp.sort_values().plot(kind="barh", color="#1F4E78")
plt.title(titulo); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 5. Aprendizaje no supervisado
#
# Ahora agrupo los países usando solo las covariables, sin la variable de ingreso. Estandarizo todas las covariables porque el clúster trabaja con distancias.

# %%
Xc = StandardScaler().fit_transform(df[covariables])

# %% [markdown]
# ### Cantidad de grupos
#
# Elijo el número de grupos combinando dos criterios, el método del codo sobre la inercia y el coeficiente de silueta.

# %%
inercias, siluetas, ks = [], [], range(2, 11)
for k in ks:
    km = KMeans(n_clusters=k, n_init=10, random_state=RANDOM_STATE).fit(Xc)
    inercias.append(km.inertia_)
    siluetas.append(silhouette_score(Xc, km.labels_))

fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].plot(list(ks), inercias, "o-"); ax[0].set_title("Método del codo")
ax[0].set_xlabel("k"); ax[0].set_ylabel("Inercia")
ax[1].plot(list(ks), siluetas, "o-", color="green"); ax[1].set_title("Coeficiente de silueta")
ax[1].set_xlabel("k"); ax[1].set_ylabel("Silueta")
plt.tight_layout(); plt.show()

# %% [markdown]
# El codo y la silueta sugieren una cantidad reducida de grupos. Ajusto K-means con el k elegido y también muestro un dendrograma del clúster jerárquico como respaldo visual.

# %%
K = 3
km = KMeans(n_clusters=K, n_init=10, random_state=RANDOM_STATE).fit(Xc)
df["Cluster"] = km.labels_

Z = linkage(Xc, method="ward")
plt.figure(figsize=(12, 4))
dendrogram(Z, no_labels=True, color_threshold=0)
plt.title("Dendrograma (clúster jerárquico, Ward)")
plt.tight_layout(); plt.show()

# %% [markdown]
# Proyecto los países en dos dimensiones con PCA para visualizar los grupos.

# %%
pca = PCA(n_components=2, random_state=RANDOM_STATE)
coords = pca.fit_transform(Xc)
plt.figure()
sc = plt.scatter(coords[:, 0], coords[:, 1], c=df["Cluster"], cmap="viridis", alpha=0.8)
plt.xlabel(f"PC1 ({pca.explained_variance_ratio_[0]*100:.0f}%)")
plt.ylabel(f"PC2 ({pca.explained_variance_ratio_[1]*100:.0f}%)")
plt.title("Países proyectados con PCA, coloreados por clúster")
plt.colorbar(sc, label="Clúster"); plt.tight_layout(); plt.show()

# %% [markdown]
# ### Descripción de los grupos
#
# Describo cada clúster por el promedio de sus indicadores, incluyendo el PIB per cápita solo para caracterizarlos.

# %%
perfil = df.groupby("Cluster")[covariables + ["PIB_per_capita"]].mean()
perfil["N_paises"] = df.groupby("Cluster").size()
perfil.T
# Out:
# Cluster                        0         1         2
# Esperanza_vida             61.28     78.00     71.39
# Fecundidad                  4.45      1.67      2.54
# Urbana_pct                 40.63     79.15     46.02
# Internet_pct               29.80     85.97     70.51
# Mortalidad_u5              79.31      9.22     24.94
# Gasto_salud_pctPIB          5.64      7.94      5.50
# Acceso_electricidad_pct    43.52     99.63     91.68
# PIB_per_capita          1,479.90 33,713.23 10,983.82
# N_paises                   37.00    113.00     67.00

# %% [markdown]
# ### Contraste con la clasificación oficial de ingreso
#
# Cruzo los grupos obtenidos con el nivel de ingreso del Banco Mundial. Aquí es donde aparece la información no evidente, los países que caen en un clúster que no corresponde al cajón donde los pone su nivel de ingreso.

# %%
tabla = pd.crosstab(df["Cluster"], df["Ingreso"])
tabla
# Out:
# Ingreso  High income  Low income  Lower middle income  Upper middle income
# Cluster
# 0                  0          20                   16                    1
# 1                 76           0                    5                   32
# 2                 10           5                   26                   26

# %%
# Ejemplos de países cuyo perfil los acerca a un grupo distinto al de su ingreso
resumen = df[["Ingreso", "Cluster", "PIB_per_capita", "Esperanza_vida", "Internet_pct"]]
resumen.sort_values(["Cluster", "Ingreso"]).head(20)
# Out:
#                              Ingreso  Cluster  PIB_per_capita  Esperanza_vida  \
# Pais
# Afghanistan               Low income        0          357.26           65.62
# Burundi                   Low income        0          301.83           62.88
# Burkina Faso              Low income        0          827.33           60.70
# Central African Republic  Low income        0          467.36           18.82
# Congo, Dem. Rep.          Low income        0          687.74           60.98
# Ethiopia                  Low income        0          982.10           66.90
# Gambia, The               Low income        0          836.24           64.86
# Guinea-Bissau             Low income        0          881.60           63.60
# Liberia                   Low income        0          744.62           61.93
# Madagascar                Low income        0          504.06           63.07
# Mali                      Low income        0          976.91           60.03
# Mozambique                Low income        0          578.27           63.01
# Malawi                    Low income        0          604.27           66.04
# Niger                     Low income        0          613.61           60.40
# Rwanda                    Low income        0        1,007.06           67.53
# Sierra Leone              Low income        0          860.37           61.27
# Somalia, Fed. Rep.        Low income        0          573.14           53.93
# South Sudan               Low income        0             NaN           57.20
# Chad                      Low income        0          966.04           54.53
# Uganda                    Low income        0          963.07           67.67
#
#                           Internet_pct
# Pais
# Afghanistan                      15.87
# Burundi                           7.14
# Burkina Faso                     25.40
# Central African Republic         13.75
# Congo, Dem. Rep.                 18.00
# Ethiopia                         17.98
# Gambia, The                      48.23
# Guinea-Bissau                    27.67
# Liberia                          30.38
# Madagascar                       17.81
# Mali                             35.20
# Mozambique                       18.96
# Malawi                           16.85
# Niger                            13.09
# Rwanda                           28.02
# Sierra Leone                     21.51
# Somalia, Fed. Rep.               27.60
# South Sudan                      78.78
# Chad                             11.17
# Uganda                            9.64

# %% [markdown]
# ## 6. Conclusiones
#
# _(Redactar a partir de los resultados. Ideas para desarrollar.)_
#
# - Qué indicadores no monetarios resultaron más determinantes para separar a los países de ingreso alto del resto, y qué dice eso sobre lo que acompaña al desarrollo económico más allá del PIB.
# - Qué tan bien predice el mejor modelo y qué aportó ajustar la probabilidad de corte.
# - Cuántos perfiles de países emergieron del clúster y en qué se diferencian.
# - Dónde el agrupamiento por datos coincidió con la clasificación oficial de ingreso y en qué casos no, relacionándolo con la pregunta y los objetivos iniciales.
#
# ## Bibliografía
#
# Banco Mundial. (2024). *World Development Indicators* \[Base de datos\]. https://data.worldbank.org
#
# _(Completar con formato APA las demás fuentes citadas en el texto.)_
